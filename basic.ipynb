# %% [markdown]
# python

# %% [markdown]
# # Heading1
# ## Heading2

# %% [markdown]
# `bulllet points`
#
# - point1
#     - subpoint1
#     - subpoint2
#         - sub subpoint
#     - subpoint3

# %%
a=10
print(a)
# Out:
# 10

# %%
text='python'
print(text[:5])
# Out:
# ytho
