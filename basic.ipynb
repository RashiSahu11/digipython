# %% [markdown]
# python

# %% [markdown]
# # Heading1
# ## Heading2

# %% [markdown]
# `bulllet points`
#
# - point1
#     - subpoint1
#     - subpoint2
#         - sub subpoint
#     - subpoint3

# %%
a=10
print(a)
# Out:
# 10

# %%
text='python'
print(text[:5])
# Out:
# ytho

# %%
num1=int(input("Enter the first number:"))
num2=int(input("Enter the second number:"))
add=num1+num2
mul=num1*num2
if mul<=1000:
    print(mul)
else:
    print(add)
# Out:
# 200000000000005443
