# %% [markdown]
# CONDITION STATEMENT

# %% [markdown]
# - if:multiple conditions
# - elif:multiple conditions
# - else:single conditions
# - nested if:multiple conditions with different concepts

# %%
marks=85
if marks>=90:
    print("Grade A")
if marks>=75:
    print('Grade B')
if marks>=60:
    print('Grade C')
if marks<60:
    print('Fail')
# Out:
# Grade B
# Grade C

# %%
marks=85
if marks>=90:
    print("Grade A")
elif marks>=75:
    print('Grade B')
elif marks>=60:
    print('Grade C')
elif marks<60:
    print('Fail') 
else:
    print('Invalid numbers')
# Out:
# Grade B

# %%
age=19
if age>=18:
    print("You are eligible to vote")
else:
    print("You are not eligible")
# Out:
# You are eligible to vote

# %%
num=19 #check whelter num is pos or neg
if num>0:
    print("number is positive")
else:
    print("number is negative")
# Out:
# number is positive

# %%
#check whelter num is even or odd
num=45
if num%2==0:
    print('number is even')
else:
    print('number is odd')
# Out:
# number is odd

# %%
#check whether a triangle is an equilateral triangle or iscoceles 
tri_1=34
tri_2=34
tri_3=53
if  tri_1==tri_2==tri_3:
    print("Triangle is equilateral ")
else:
    print("Triangle is isosceles")
# Out:
# Triangle is isosceles

# %%
#check whether alphabet is vowel or consonant
alphabet='m'
if alphabet=='a':
    print("Alphabet is VOWEL")
elif alphabet=='e':
    print('Alphabet is VOWEL')
elif alphabet=='i':
    print('VOWEL')
elif alphabet=='o':
    print("VOWEL")
elif alphabet=='u':
    print("VOWEL") 
else:
    print("CONSONENT")
# Out:
# CONSONENT

# %%
radius=9
area=3.14*radius*radius
print("Area of circle:",area)
# Out:
# Area of circle: 254.34

# %%
sq_1=23
sq_2=25
if sq_1==sq_2:
    print('sides are equal')
else:
    print("sides are not equal")
# Out:
# sides are not equal

# %%
basicsal=50000
DA=5/100*50000
HRA=10/100*50000
grosssal=basicsal+DA+HRA
print("Gross Salary of a emp:",grosssal)
# Out:
# Gross Salary of a emp: 57500.0

# %%
#NESTED IF
username=input("Enter your username:")
email=input("Enter your email:")
password=input("Enter your password:")
c_password=input("Confirm your password:")

if len(username)>=8 and len(username)<=15:
    if'@' in email and '.' in email:
        if len(password)>=8 and len(password)<=15:
            if password==c_password:
                print("Registration successful")
            else:
                print("Pasword doesn't match")
        else:
            print("password must be between 8 and 15 characters")
    else:
        print("Invalid email format")
else:
    print("username must be between 8 and 15 characters")
# Out:
# username must be between 8 and 15 characters

# %%
stu_name=input("Enter student's name:")
stu_marks=int(input("Enter student's marks:"))
age=int(input("Enter age:"))
if stu_marks>=60 and age>=18:
    print("Eligible foe admission")
else:
    print('Not eligible for admission')
# Out:
# Not eligible for admission

# %%
stu_marks=int(input("Enter student's marks:"))
age=int(input("Enter age:"))
if stu_marks>=60 :
    if age>=18:
        print("Admission granted")
    else:
        print("Age is not elligible")
else:
    print("Admission not granted")
# Out:
# Admission granted

# %%
#Take input from user for n variable and calculate the sum of those n numbers
num_1=int(input("Enter the first number:"))
num_2=int(input("Enter the second number:"))
num_3=int(input('Enter the third number:'))
addition=num_1+num_2+num_3
print("Sum of the given numbers:",addition)
# Out:
# Sum of the given numbers: 60

# %%
#Take a number from the user and count digits in a number
num=(input("Enter the number:"))
print(len(num))
# Out:
# 4

# %%
#Write a Python program that checks whether a number is:positive,negative or zero
num= int(input ("Enter number:"))
if num>0:
    print("number is positive")
elif num==0:
    print("number is zero") 
else:     
    print("number is negative")
# Out:
# number is negative

# %%
x=0
y=10
if x and y/x:
    print('valid')
else:
    print('Invalid')
# Out:
# Invalid

# %%
x=10
y=5
if x>5==y:
    print("Match")
else:
    print("No match")
# Out:
# Match

# %%
s='abcdefg'
print(s[::3][::-1])
# Out:
# gda

# %%
a=[1,2,3]
b=a
a=a+[4]
print(b)
# Out:
# [1, 2, 3]

# %%
a={1,2.3}
b=a
a.clear()
print(b)
# Out:
# set()
