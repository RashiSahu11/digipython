# %%
a=10
b=3
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a%b) #return remainder
print(a//b) #return quoitent
print(a**b) #power
# Out:
# 13
# 7
# 30
# 3.3333333333333335
# 1
# 3
# 1000

# %%
a=10
a+=5
print(a)
# Out:
# 15

# %%
a-=5
print(a)
# Out:
# 10

# %%
a/=5
print(a)
# Out:
# 2.0

# %%
a%=5
print(a)
# Out:
# 2.0

# %%
a//=5
print(a)
# Out:
# 0.0

# %%
a**=5
print(a)
# Out:
# 0.0

# %% [markdown]
# logical operator

# %%
x=10
y=5
z=7
x>y and x>z
# Out:
# True

# %%
x<y or x>z
# Out:
# True

# %%
not x<y
# Out:
# True

# %%
x is y
# Out:
# False

# %%
x is  not y
# Out:
# True

# %%
email="rashi11sahu@gmail.com"
'@' in email
# Out:
# True

# %%
email="rashi11sahu@gmail.com"
'#' in email
# Out:
# False

# %%
count='python'
if 'a','e','i','o','u' in count:
    print(len(count))
# Out:
#   Cell In[1], line 2
#     if 'a','e','i','o','u' in count:
#           ^
# SyntaxError: invalid syntax
