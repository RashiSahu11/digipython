# %%
name='rashi' 
print(name)
# Out:
# rashi

# %%
poem= '''johny johny yes papa
eating sugar no papa'''
print(poem) # multiline string
# Out:
# johny johny yes papa
# eating sugar no papa

# %%
lst=['apple','cherry','strawberry','avacado']
print(lst)
# Out:
# ['apple', 'cherry', 'strawberry', 'avacado']

# %%
tuple=(2,6,4,8,0,3,5,4)
print(tuple)
# Out:
# (2, 6, 4, 8, 0, 4)

# %%
set = {2,3,4,2,0,9,7,5,4,0,9,7,6}
print(set)
# Out:
# {0, 2, 3, 4, 5, 6, 7, 9}

# %%
student={
    'name':'Rashi',
    'age':19,
    'course':'Python'
}
print(student)
# Out:
# {'name': 'Rashi', 'age': 19, 'course': 'Python'}

# %%
type(name)
# Out:
# str

# %% [markdown]
# 'TYPE CASTING' process of converting one datatype into another

# %%
a=int(input("Enter the first number:"))
b=int(input("Enter the second number"))
print(a+b)
# Out:
# 20

# %%
x=10
y=3
print(x/y)
# Out:
# 3.3333333333333335
